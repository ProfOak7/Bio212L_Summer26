# %%
import pandas as pd
import statistics
from statistics import mean, stdev
from scipy.stats import sem
import scipy.stats as stats
import matplotlib.pyplot as plt
#include if using a jupyter notebook, remove if using a .py file
# %matplotlib inline

# %%
#Optional - Set figure resolution to 300dpi
import matplotlib as mpl
# %matplotlib inline
plt.rcParams['figure.dpi'] = 300
plt.rcParams['savefig.dpi'] = 300

# %%
#Import the excel file
df = pd.read_excel (r'./Natural_Selection_Lab2.xlsx', index_col = 0)
df
# Out:
#                    G1   G2   G3   G4
# Type
# Forceps            97  106    0    0
# Spoon              79  262  374  760
# Fork              114  174  158    0
# Knife               4    0    0    0
# Tongue Depressor  127  291  382  489

# %%
df = df.transpose()
df
# Out:
# Type  Forceps  Spoon  Fork  Knife  Tongue Depressor
# G1         97     79   114      4               127
# G2        106    262   174      0               291
# G3          0    374   158      0               382
# G4          0    760     0      0               489

# %%
fig, ax = plt.subplots()
df.plot.line(ax = ax, y = 'Forceps', marker = 'o')
df.plot.line(ax = ax, y = 'Spoon', marker = 'o')
df.plot.line(ax = ax, y = 'Fork', marker = 'o')
df.plot.line(ax = ax, y = 'Knife', marker = 'o')
df.plot.line(ax = ax, y = 'Tongue Depressor', marker = 'o')

ax.legend(loc='upper left', bbox_to_anchor=(1, 1))
ax.set_xlabel("Generation Number")
ax.set_ylabel("Total Offspring")
ax.set_title("Total Offspring Per Generation")
# Out:
# Text(0.5, 1.0, 'Total Offspring Per Generation')

# %%
#Import the excel file
df = pd.read_excel (r'./Natural_Selection_Lab2_gs.xlsx', index_col = 0)
df
# Out:
#                    G1  G2  G3  G4
# Type
# Forceps             2   2   0   0
# Spoons              2   2   3   4
# Forks               2   2   2   0
# Knives              2   0   0   0
# Tongue Depressors   3   5   6   7

# %%
df = df.transpose()
df
# Out:
# Type  Forceps  Spoons  Forks  Knives  Tongue Depressors
# G1          2       2      2       2                  3
# G2          2       2      2       0                  5
# G3          0       3      2       0                  6
# G4          0       4      0       0                  7

# %%
fig, ax = plt.subplots()
df.plot.line(ax = ax, y = 'Forceps', marker = 'o')
df.plot.line(ax = ax, y = 'Spoons', marker = 'o')
df.plot.line(ax = ax, y = 'Forks', marker = 'o')
df.plot.line(ax = ax, y = 'Knives', marker = 'o')
df.plot.line(ax = ax, y = 'Tongue Depressors', marker = 'o')

ax.legend(loc='upper left', bbox_to_anchor=(1, 1))
ax.set_xlabel("Generation Number")
ax.set_ylabel("Group Size")
ax.set_title("Group Size Per Generation")
# Out:
# Text(0.5, 1.0, 'Group Size Per Generation')
